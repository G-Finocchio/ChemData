# %%
# !pip install .
# Out:
# Processing c:\githubphaidra_code\chemdata\shlasso-kmfm-paper\python_package
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for Strong_hierarchical_lasso: filename=strong_hierarchical_lasso-0.1.0-py3-none-any.whl size=78244 sha256=7d83aa06c07a8c0a74492d27dc92a2f24c522c179d183c41cdaef03286a03dec
#   Stored in directory: C:\Users\morariu\AppData\Local\Temp\pip-ephem-wheel-cache-fx1psm_s\wheels\03\57\d2\0a694e74b113a8155157188d6bef0de310a8d2f0e702a1915a
# Successfully built Strong_hierarchical_lasso
# ...
